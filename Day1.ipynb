# %%
dataset = "deez.csv"
print(f"variable intialized: {dataset}")
# Out:
# variable intialized: deez.csv

# %%
X = 100
print(f"{X}")
# Out:
# 100

# %%
Y = X +5
print(f"{Y}")
# Out:
# 105

# %%
print(f"valX: {X}")
print(f"valY: {Y}")
# Out:
# valX: 100
# valY: 105

# %%
x = [2,4,1,3,7,1]

x.sort()

x.pop(0)
x.pop(len(x)-1)

answer = sum(x)/len(x)

print(answer)
# Out:
# 2.5

# %%
import math
x = 60
biggest = math.sqrt(x)
biggest1 = math.floor(biggest)
mylist = []
for i in range(1, x):
    if (x % i) == 0:
        mylist.append(i)

print(mylist)
# Out:
# [1, 2, 3, 4, 5, 6, 10, 12, 15, 20, 30]
