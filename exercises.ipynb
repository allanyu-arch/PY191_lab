# %%
import pandas as pd; import numpy as np;
temp_2d = np.array([[64.0, 66.5, 70.2], 
                    [77.1, 75.6, 71.3]])
temp_2d[:,1][(temp_2d>70)[:,1]]
print(temp_2d.mean(axis=0, keepdims=True))
# min along the columns
temp_2d.min(axis=0, keepdims=True)


mylist = np.array([8,7,6,2,9,6,7])
temperatures_f = np.array([58.2, 64.0, 69.3, 74.1, 77.8, 76.2, 71.0, 65.4])
im_mad_f = abs(temperatures_f-temperatures_f.mean())/len(temperatures_f)
median = np.quantile(temperatures_f, .5)
Q3 = np.quantile(temperatures_f, .75)
Q1 = np.quantile(temperatures_f, .25)
im_mad_f2 = abs(temperatures_f-median)/len(temperatures_f)
print(im_mad_f2.sum())
# print(temperatures_f.mean())
print(median)
print(temperatures_f.mean())
print(Q3)
print(Q1)
print((Q3-Q1)/2)
# Out:
# [[70.55 71.05 70.75]]
# 5.274999999999999
# 70.15
# 69.5
# 74.625
# 65.05000000000001
# 4.787499999999994
