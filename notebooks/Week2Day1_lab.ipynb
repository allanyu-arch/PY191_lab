# %%
import pandas as pd; import matplotlib.pyplot as plt; import numpy as np
dataframe_df = pd.read_csv("station_weather.csv")
dataframe_df.head()
# Out:
#          date station_id  hour  temperature_f  humidity_pct  wind_mph
# 0  2026-06-15    RISE-01     6           59.7          87.3       6.7
# 1  2026-06-15    RISE-01     8           60.2          93.8       9.1
# 2  2026-06-15    RISE-01    10           65.0          79.9       6.3
# 3  2026-06-15    RISE-01    12           71.6          64.1       7.3
# 4  2026-06-15    RISE-01    14           70.6          61.0       4.8

# %%
string = "Happy Birthday Jace"
words_arr = np.array(list(string))
i = 0
while i < len(words_arr):
    if words_arr[i] == " ":
        i
    if i%7 == 0 and i>0:
        words_arr[i] = "7"

    i+=1

print(words_arr)
# Out:
# ['H' 'a' 'p' 'p' 'y' ' ' 'B' '7' 'r' 't' 'h' 'd' 'a' 'y' ' ' 'J' 'a' 'c'
#  'e']

# %%
dates = dataframe_df["date"].to_numpy
locations = dataframe_df["station_id"].to_numpy()
hours = dataframe_df["hour"].to_numpy()
hours1 = hours.unique()
temperatures = dataframe_df["temperature_f"].to_numpy
for hour in hours:
