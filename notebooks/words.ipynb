# %%
import pandas as pd; import numpy as np; import os; import string

#rank by frequency
#multiply rank by frequency

original = "I cannot help it; reason has nothing to do with it; I love her against reason, but who would as soon love me for my own sake, as she would love the beggar at the corner."
rank = []
counts = {}
string1 = original.split(' ')
clean_words = [
]

for word in string1:
    clean_word = word.strip(string.punctuation)
    clean_words.append(clean_word)

for i in range(len(clean_words)):
    if clean_words[i] in counts:
        counts[clean_words[i]] += 1
    else:
        counts[clean_words[i]] = 1

sort_dict = dict(sorted(counts.items(), key=lambda item: item[1], reverse=True))

print(sort_dict)

for i, (word, count) in enumerate(sort_dict.items()):
    print(f"rank {i+1}: {word}: {count}")

newlist = []

index = 1
for word in sort_dict:
    newlist.append(sort_dict[word]*1)
    index+=1
# Out:
# {'love': 3, 'I': 2, 'it': 2, 'reason': 2, 'would': 2, 'as': 2, 'the': 2, 'cannot': 1, 'help': 1, 'has': 1, 'nothing': 1, 'to': 1, 'do': 1, 'with': 1, 'her': 1, 'against': 1, 'but': 1, 'who': 1, 'soon': 1, 'me': 1, 'for': 1, 'my': 1, 'own': 1, 'sake': 1, 'she': 1, 'beggar': 1, 'at': 1, 'corner': 1}
# rank 1: love: 3
# rank 2: I: 2
# rank 3: it: 2
# rank 4: reason: 2
# rank 5: would: 2
# rank 6: as: 2
# rank 7: the: 2
# rank 8: cannot: 1
# rank 9: help: 1
# rank 10: has: 1
# rank 11: nothing: 1
# rank 12: to: 1
# rank 13: do: 1
# rank 14: with: 1
# rank 15: her: 1
# rank 16: against: 1
# rank 17: but: 1
# rank 18: who: 1
# rank 19: soon: 1
# rank 20: me: 1
# rank 21: for: 1
# rank 22: my: 1
# rank 23: own: 1
# rank 24: sake: 1
# rank 25: she: 1
# rank 26: beggar: 1
# rank 27: at: 1
# rank 28: corner: 1
